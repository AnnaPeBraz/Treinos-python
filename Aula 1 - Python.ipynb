# %%
#importar as bibliotecas
import pyautogui as pag #faz as automaçoes do mouse e teclado
import time #controla o tempo do programa
import pyperclip #permite copiar e colar com o python

pag.PAUSE = 1 #Faz com que a cada comando, ele aguarde 1s
pag.alert("Por favor nao mexa no pc.")
#Passo 1: Entrar no sistema
pyautogui.hotkey('ctrl', 't')
link = "https://drive.google.com/drive/folders/1_ROlMWjLehCkYI9eXe4rSbLulLehrz-j"
pyperclip.copy(link)
pyautogui.hotkey('ctrl', 'v')
#pyautogui.write nao funciona por causa do autocomplete
pyautogui.press('enter')
time.sleep(5)

#Passo 2: Entrar na pasta da aula1 e selecionar o arquivo
pyautogui.click(425,436)
pyautogui.click(1105,194)

#Passo 3: fazer download da base de vendas
pyautogui.click(946, 627)
time.sleep(10)

#pyautogui.click(x,y,clicks=n)

# %%
#Passo 4: calcular os indicadores da base de vendas (quantidade de produtos e faturamento)
import pandas as pd

tabela = pd.read_excel(r"C:\Users\ninha\Downloads\Vendas - Dez.xlsx")
#para ler em outa aba, usar no final , sheet_name=n, sendo n o numero da aba
#p.e.:pd.read_excel(r"C:\Users\ninha\Downloads\Vendas - Dez.xlsx, sheet_name=3")
display(tabela)

faturamento = tabela["Valor Final"].sum()
qtdProdutos = tabela["Quantidade"].sum()
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
#Passo 5: entrar no meu email
#para enviar um email para voce mesmo: seuemai+qlqrcoisa@gmail.com
linkgmail = "https://mail.google.com/mail/u/0/?ogbl#inbox"
pag.hotkey('ctrl','t')
pyperclip.copy(linkgmail)
pag.hotkey('ctrl', 'v')
pag.press('enter')
time.sleep(8)

#Passo 6: criar email
pag.click(109,199)
time.sleep(2)
pag.write("annap.0103+lala@gmail.com")
pag.press("tab")
#preencher o assunto
pag.press("tab")
pag.write("Sera que vai?")
#preencher o email
pag.press("tab")
pag.write(f"""
Prezados,
Segue os numero tudo ai que tu pediro:

Faturamento: R${faturamento:,.2f}

Quantidade de Produtos: {qtdProdutos}
""")

#Passo 7: enviar email
pag.hotkey('ctrl', 'enter')

# %%
time.sleep(5)
pyautogui.position()
# Out:
# Point(x=109, y=199)
